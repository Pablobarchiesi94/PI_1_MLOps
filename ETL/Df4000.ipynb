# %% [markdown]
# <a href="https://colab.research.google.com/github/Pablobarchiesi94/PI_1_MLOps/blob/main/ETL/Df4000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Me conecto al Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importo la libreria a utilizar

# %%
import pandas as pd

# %% [markdown]
# Carga del dataset

# %%
df= pd.read_csv('/content/drive/MyDrive/df_final_limpio.csv')

# %%
df.head(5)
# Out:
#       id           belongs_to_collection      budget  \
# 0    862            Toy Story Collection  30000000.0
# 1   8844                             NaN  65000000.0
# 2  15602       Grumpy Old Men Collection         0.0
# 3  31357                             NaN  16000000.0
# 4  11862  Father of the Bride Collection         0.0
#
#                                genres original_language  \
# 0   ['Animation', 'Comedy', 'Family']                en
# 1  ['Adventure', 'Fantasy', 'Family']                en
# 2               ['Romance', 'Comedy']                en
# 3      ['Comedy', 'Drama', 'Romance']                en
# 4                          ['Comedy']                en
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                                 production_companies  \
# 0                        ['Pixar Animation Studios']
# 1  ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 2                 ['Warner Bros.', 'Lancaster Gate']
# 3         ['Twentieth Century Fox Film Corporation']
# 4   ['Sandollar Productions', 'Touchstone Pictures']
#
#            production_countries release_date  ...  \
# 0  ['United States of America']   1995-10-30  ...
# 1  ['United States of America']   1995-12-15  ...
# 2  ['United States of America']   1995-12-22  ...
# 3  ['United States of America']   1995-12-22  ...
# 4  ['United States of America']   1995-02-10  ...
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title vote_average vote_count release_year  \
# 0                    Toy Story          7.7     5415.0         1995
# 1                      Jumanji          6.9     2413.0         1995
# 2             Grumpier Old Men          6.5       92.0         1995
# 3            Waiting to Exhale          6.1       34.0         1995
# 4  Father of the Bride Part II          5.7      173.0         1995
#
#       return  DiaSemana        Mes  \
# 0  12.451801      Lunes    Octubre
# 1   4.043035    Viernes  Diciembre
# 2   0.000000    Viernes  Diciembre
# 3   5.090760    Viernes  Diciembre
# 4   0.000000    Viernes    Febrero
#
#                                                 cast  \
# 0  ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim...
# 1  ['Robin Williams', 'Jonathan Hyde', 'Kirsten D...
# 2  ['Walter Matthau', 'Jack Lemmon', 'Ann-Margret...
# 3  ['Whitney Houston', 'Angela Bassett', 'Loretta...
# 4  ['Steve Martin', 'Diane Keaton', 'Martin Short...
#
#                                                 crew
# 0  ['John Lasseter', 'Joss Whedon', 'Andrew Stant...
# 1  ['Larry J. Franco', 'Jonathan Hensleigh', 'Jam...
# 2  ['Howard Deutch', 'Mark Steven Johnson', 'Mark...
# 3  ['Forest Whitaker', 'Ronald Bass', 'Ronald Bas...
# 4  ['Alan Silvestri', 'Elliot Davis', 'Nancy Meye...
#
# [5 rows x 24 columns]

# %%
# Obtengo 4000 filas al azar
df_4000 = df.sample(n=4000, random_state=40)  # aplico random_state

# Recorto el dataframe original para quedarme con las 2000 filas seleccionadas
df_recortado = df_4000.copy()

# %%
df_recortado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 15318 to 37415
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   belongs_to_collection  406 non-null    object
#  2   budget                 4000 non-null   float64
#  3   genres                 3845 non-null   object
#  4   original_language      4000 non-null   object
#  5   overview               3912 non-null   object
#  6   popularity             4000 non-null   float64
#  7   production_companies   3087 non-null   object
#  8   production_countries   3517 non-null   object
#  9   release_date           4000 non-null   object
#  10  revenue                4000 non-null   float64
#  11  runtime                3982 non-null   float64
#  12  spoken_languages       3748 non-null   object
#  13  status                 3997 non-null   object
#  14  tagline                1884 non-null   object
#  15  title                  4000 non-null   object
#  16  vote_average           4000 non-null   float64
#  17  vote_count             4000 non-null   float64
#  18  release_year           4000 non-null   int64
#  19  return                 4000 non-null   float64
#  20  DiaSemana              4000 non-null   object
#  21  Mes                    4000 non-null   object
#  22  cast                   4000 non-null   object
#  23  crew                   4000 non-null   object
# dtypes: float64(7), int64(2), object(15)
# memory usage: 781.2+ KB

# %%
df_recortado
# Out:
#            id     belongs_to_collection      budget  \
# 15318   46011                       NaN         0.0
# 41836  227245                       NaN         0.0
# 41412   56525  Shadow Boxing Collection   6000000.0
# 12322   13495                       NaN  24000000.0
# 39348  347870                       NaN         0.0
# ...       ...                       ...         ...
# 39644   72955                       NaN         0.0
# 24581   19444                       NaN         0.0
# 28259  142115                       NaN         0.0
# 7205    18329                       NaN         0.0
# 37415  361249                       NaN         0.0
#
#                                                   genres original_language  \
# 15318  ['Drama', 'Comedy', 'Music', 'Romance', 'Family']                en
# 41836                               ['Drama', 'Romance']                pl
# 41412                                         ['Action']                ru
# 12322                                         ['Action']                es
# 39348                                         ['Comedy']                en
# ...                                                  ...               ...
# 39644                                         ['Comedy']                ru
# 24581                                         ['Horror']                en
# 28259                               ['Drama', 'Romance']                en
# 7205                                ['Drama', 'Romance']                zh
# 37415                                          ['Drama']                hi
#
#                                                 overview  popularity  \
# 15318  Washington hostess Sally Adams becomes a Truma...    0.078792
# 41836  A subtle, almost quasi-documentary tale of a c...    0.150180
# 41412  When Artem Kolchin, Denis Nikiforov, arrives i...    0.471086
# 12322  In 17th century Spain Diego Alatriste, a brave...    5.035414
# 39348  Freshman Neil's Vanguard stories are all he ca...    0.957564
# ...                                                  ...         ...
# 39644  The Prohibition years. Chicago bootleggers suf...    0.231954
# 24581  Killer Krishnas, Bondage Beauties, Stupid Stud...    0.000680
# 28259  FIVE DANCES, written and directed by Alan Brow...    1.825600
# 7205   Lai and his boyfriend, Ho, arrive in Argentina...    5.933971
# 37415  Behind the magnificent Taj Mahal lies a cluste...    0.625451
#
#                                     production_companies  \
# 15318                                                NaN
# 41836                          ['Zespól Filmowy "Kadr"']
# 41412                            ['Central Partnership']
# 12322  ['Twentieth Century Fox Film Corporation', 'Es...
# 39348                                     ['Arts+Labor']
# ...                                                  ...
# 39644                            ['Одесская киностудия']
# 24581                                                NaN
# 28259                          ['Perry Street Pictures']
# 7205   ['Block 2 Pictures', 'Jet Tone Production', 'B...
# 37415                                                NaN
#
#                   production_countries release_date  ...  tagline  \
# 15318                              NaN   1953-03-25  ...      NaN
# 41836                       ['Poland']   1958-08-04  ...      NaN
# 41412                       ['Russia']   2007-10-18  ...      NaN
# 12322                        ['Spain']   2006-09-01  ...      NaN
# 39348     ['United States of America']   2016-03-13  ...      NaN
# ...                                ...          ...  ...      ...
# 39644  ['Ukraine', 'Russia', 'Poland']   1989-04-18  ...      NaN
# 24581               ['United Kingdom']   1991-01-01  ...      NaN
# 28259     ['United States of America']   2013-06-19  ...      NaN
# 7205                     ['Hong Kong']   1997-05-17  ...      NaN
# 37415                        ['India']   2016-04-22  ...      NaN
#
#                         title vote_average vote_count release_year    return  \
# 15318           Call Me Madam          8.5        2.0         1953  0.000000
# 41836  The Last Day of Summer          6.3        4.0         1958  0.000000
# 41412  Boj S Tenyu 2: Revansh          5.6        5.0         2007  1.861983
# 12322               Alatriste          5.6       62.0         2006  0.971748
# 39348                   Slash          6.6       17.0         2016  0.000000
# ...                       ...          ...        ...          ...       ...
# 39644                 Déjà vu          7.9        5.0         1989  0.000000
# 24581               Bad Karma          0.0        0.0         1991  0.000000
# 28259             Five Dances          6.6       20.0         2013  0.000000
# 7205           Happy Together          7.7      103.0         1997  0.000000
# 37415      Nil Battey Sannata          6.8        8.0         2016  0.000000
#
#        DiaSemana         Mes  \
# 15318  Miércoles       Marzo
# 41836      Lunes      Agosto
# 41412     Jueves     Octubre
# 12322    Viernes  Septiembre
# 39348    Domingo       Marzo
# ...          ...         ...
# 39644     Martes       Abril
# 24581     Martes       Enero
# 28259  Miércoles       Junio
# 7205      Sábado        Mayo
# 37415    Viernes       Abril
#
#                                                     cast  \
# 15318  ['Ethel Merman', "Donald O'Connor", 'Vera-Elle...
# 41836               ['Irena Laskowska', 'Jan Machulski']
# 41412  ['Denis Nikiforov', 'Andrei Panin', 'Elena Pan...
# 12322  ['Viggo Mortensen', 'Elena Anaya', 'Unax Ugald...
# 39348  ['Michael Ian Black', 'Burnie Burns', 'Violett...
# ...                                                  ...
# 39644  ['Jerzy Stuhr', 'Galina Petrova', 'Nikolai Kar...
# 24581                                  ['Julius Barnet']
# 28259  ['Ryan Steele', 'Reed Luplau', 'Catherine Mill...
# 7205   ['Tony Leung Chiu-Wai', 'Leslie Cheung', 'Chan...
# 37415  ['Swara Bhaskar', 'Ratna Pathak', 'Pankaj Trip...
#
#                                                     crew
# 15318                                    ['Walter Lang']
# 41836  ['Tadeusz Konwicki', 'Tadeusz Konwicki', 'Jan ...
# 41412           ['Anton Megerdichev', 'Aleksei Sidorov']
# 12322  ['José Salcedo', 'Arturo Pérez-Reverte', 'Anto...
# 39348     ['Clay Liford', 'Clay Liford', 'David Fabelo']
# ...                                                  ...
# 39644  ['Juliusz Machulski', 'Aleksandr Borodyanskiy'...
# 24581                   ['Alex Chandon', 'Alex Chandon']
# 28259                       ['Alan Brown', 'Alan Brown']
# 7205   ['Christopher Doyle', 'Wong Kar-wai', 'Wong Ka...
# 37415  ['Ashwiny Iyer Tiwari', 'Ajay G Rai', 'Alan Mc...
#
# [4000 rows x 24 columns]

# %%
# Guardo el df de 4000 filas

df_recortado.to_csv('df_4000.csv', index=False)

# %%
#Guardo df de 4000 filas
df_recortado.to_csv('/content/drive/MyDrive/df_4000.csv', index=False)
