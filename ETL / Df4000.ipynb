# %% [markdown]
# <a href="https://colab.research.google.com/github/Pablobarchiesi94/PI_1_MLOps/blob/main/ETL%20/%20Df4000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Me conecto al Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importo la libreria a utilizar

# %%
import pandas as pd

# %% [markdown]
# Carga del dataset

# %%
df= pd.read_csv('/content/drive/MyDrive/df_final_limpio.csv')

# %%
df.head(5)
# Out:
#       id      budget                              genres  popularity  \
# 0    862  30000000.0   ['Animation', 'Comedy', 'Family']   21.946943
# 1   8844  65000000.0  ['Adventure', 'Fantasy', 'Family']   17.015539
# 2  15602         0.0               ['Romance', 'Comedy']   11.712900
# 3  31357  16000000.0      ['Comedy', 'Drama', 'Romance']    3.859495
# 4  11862         0.0                          ['Comedy']    8.387519
#
#   release_date      revenue                        title  vote_average  \
# 0   1995-10-30  373554033.0                    Toy Story           7.7
# 1   1995-12-15  262797249.0                      Jumanji           6.9
# 2   1995-12-22          0.0             Grumpier Old Men           6.5
# 3   1995-12-22   81452156.0            Waiting to Exhale           6.1
# 4   1995-02-10   76578911.0  Father of the Bride Part II           5.7
#
#    vote_count  release_year     return DiaSemana        Mes  \
# ...

# %%
# Obtengo 4000 filas al azar
df_4000 = df.sample(n=4000, random_state=40)  # aplico random_state

# Recorto el dataframe original para quedarme con las 4000 filas seleccionadas
df_recortado = df_4000.copy()

# %%
df_recortado.head(5)
# Out:
#            id      budget                                             genres  \
# 15318   46011         0.0  ['Drama', 'Comedy', 'Music', 'Romance', 'Family']
# 41836  227245         0.0                               ['Drama', 'Romance']
# 41412   56525   6000000.0                                         ['Action']
# 12322   13495  24000000.0                                         ['Action']
# 39348  347870         0.0                                         ['Comedy']
#
#        popularity release_date     revenue                   title  \
# 15318    0.078792   1953-03-25         0.0           Call Me Madam
# 41836    0.150180   1958-08-04         0.0  The Last Day of Summer
# 41412    0.471086   2007-10-18  11171900.0  Boj S Tenyu 2: Revansh
# 12322    5.035414   2006-09-01  23321954.0               Alatriste
# 39348    0.957564   2016-03-13         0.0                   Slash
#
#        vote_average  vote_count  release_year    return  DiaSemana  \
# ...

# %%
df_recortado.shape[0]
# Out:
# 4000

# %%
# Guardo el df de 4000 filas

df_recortado.to_csv('df_4000.csv', index=False)

# %%
#Guardo df de 4000 filas
df_recortado.to_csv('/content/drive/MyDrive/df_4000.csv', index=False)
